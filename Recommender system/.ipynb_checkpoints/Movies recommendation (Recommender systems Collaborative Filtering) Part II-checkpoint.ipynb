# %% [markdown]
# # Item-Based Collaborative Filtering

# %% [markdown]
# As before, we'll start by importing the MovieLens 100K data set into a pandas DataFrame:

# %%
import pandas as pd
import numpy as np

# %%
r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('C:/Users/YsfEss/Desktop/ml-100k/u.data', sep='\t', names=r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ['movie_id', 'title']
movies = pd.read_csv('C:/Users/YsfEss/Desktop/ml-100k/u.item', sep='|', names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

# %% [markdown]
# Now we'll pivot this table to construct a nice matrix of users and the movies they rated. NaN indicates missing data, or movies that a given user did not watch:

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %% [markdown]
# Pandas has a built-in corr() method that will compute a correlation score for every column pair in the matrix! This gives us a correlation score between every pair of movies (where at least one user rated both movies - otherwise NaN's will show up.)

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %% [markdown]
# However, we want to avoid insignificant results that happened due to just a handful of users that happened to rate the same pair of movies. In order to restrict our results to movies that lots of people rated together - and also give us more popular results that are more easily recongnizable - we'll use the min_periods argument to throw out results where fewer than 100 users rated a given movie pair:

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %% [markdown]
# Now let's produce some movie recommendations for user ID 0, who I manually added to the data set as a test case. This guy really likes The Shawshank Redemption and Toy Story, but hated Star Wars.

# %%
myR=[]
for i in range(1664):
    if i==1523: #index of Toy story
        myR.append(5)
    elif i==1317: #index of Shawshank
        myR.append(5)
    elif i==1398: # index of star wars
        myR.append(1)
    else:
        myR.append(None)

# %%
userRatings.loc[0]=myR
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Shawshank Redemption, The (1994)    5.0
# Star Wars (1977)                    1.0
# Toy Story (1995)                    5.0
# Name: 0, dtype: float64

# %% [markdown]
# Now, let's go through each movie I rated one at a time, and build up a list of possible recommendations based on the movies similar to the ones I rated.
#
# So for each movie I rated, I'll retrieve the list of similar movies from our correlation matrix. I'll then scale those correlation scores by how well I rated the movie they are similar to, so movies similar to ones I liked count more than movies similar to ones I hated:

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print ("Adding similar movies for " + myRatings.index[i] + "...")
    # Retrieve similar movies to this one that I rated
    sims = corrMatrix[myRatings.index[i]].dropna()
    # Now scale its similarity by how well I rated this movie
    sims = sims.map(lambda x: x * myRatings[i])
    # Add the score to the list of similarity candidates
    simCandidates = simCandidates.append(sims)
    
#Glance at our results so far:
print ("Sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# Adding similar movies for Shawshank Redemption, The (1994)...
# Adding similar movies for Star Wars (1977)...
# Adding similar movies for Toy Story (1995)...
# Sorting...
# Shawshank Redemption, The (1994)    5.000000
# Toy Story (1995)                    5.000000
# Glory (1989)                        2.308311
# Beauty and the Beast (1991)         2.214800
# Mask, The (1994)                    2.164274
# Cinderella (1950)                   2.141860
# That Thing You Do! (1996)           2.139680
# Lion King, The (1994)               2.133892
# Aladdin (1992)                      2.058653
# African Queen, The (1951)           1.989368
# dtype: float64

# %% [markdown]
# This is starting to look like something useful! Note that for some of the ratings some movies might came up more than once, because they were similar to more than one movie I rated. We'll use groupby() to add together the scores from movies that show up more than once, so they'll count more:

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# Toy Story (1995)                    6.345393
# Shawshank Redemption, The (1994)    6.340359
# Aladdin (1992)                      4.184556
# Glory (1989)                        3.982967
# Apollo 13 (1995)                    3.736289
# Lion King, The (1994)               3.711656
# Liar Liar (1997)                    3.635836
# Raiders of the Lost Ark (1981)      3.628396
# Top Gun (1986)                      3.623639
# American President, The (1995)      3.611808
# dtype: float64

# %% [markdown]
# The last thing we have to do is filter out movies I've already rated, as recommending a movie I've already watched isn't helpful:

# %%
filteredSims = simCandidates.drop(myRatings.index)
filteredSims.head(10)
# Out:
# Aladdin (1992)                    4.184556
# Glory (1989)                      3.982967
# Apollo 13 (1995)                  3.736289
# Lion King, The (1994)             3.711656
# Liar Liar (1997)                  3.635836
# Raiders of the Lost Ark (1981)    3.628396
# Top Gun (1986)                    3.623639
# American President, The (1995)    3.611808
# Jurassic Park (1993)              3.509747
# Braveheart (1995)                 3.475484
# dtype: float64

# %% [markdown]
# Not the most sophisticated movie recommender but does will detecting some stuff, by recommending a lot of family movies similar to toy story such as lion king, Aladdin and Liar Liar. Also, Glory can be seen similar to Shawshank in the fact that both have the great actor Morgan Freeman in them, and that obviously have a role in liking a movie or not.
#
# Notice also that Apollo 13, The american president and Braveheart all are released same year which is 1995, after some research I found that the year 1995 is considered by many to be one of, if not the best year for movies so, including shawshank redemption which is one of the best movies ever, made it that the movies recommended have to be one of the best movies aswell and from there we get all this different genres of movies that are great movies overall.
